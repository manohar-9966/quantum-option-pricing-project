# %% [markdown]
# <a href="https://colab.research.google.com/github/manohar-9966/quantum-option-pricing-project/blob/main/quantum_option_pricing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qiskit
# !pip install qiskit-finance
# !pip install numpy
# !pip install matplotlib
# !pip install pandas
# Out:
# Requirement already satisfied: qiskit in /usr/local/lib/python3.12/dist-packages (2.3.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.21 in /usr/local/lib/python3.12/dist-packages (from qiskit) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit) (5.7.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit) (4.15.0)
# Requirement already satisfied: qiskit-finance in /usr/local/lib/python3.12/dist-packages (0.4.1)
# Requirement already satisfied: qiskit>=0.45 in /usr/local/lib/python3.12/dist-packages (from qiskit-finance) (2.3.1)
# Requirement already satisfied: qiskit-algorithms>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-finance) (0.4.0)
# Requirement already satisfied: qiskit-optimization>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-finance) (0.7.0)
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.12/dist-packages (from qiskit-finance) (1.16.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from qiskit-finance) (2.0.2)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/dist-packages (from qiskit-finance) (5.9.5)
# Requirement already satisfied: fastdtw in /usr/local/lib/python3.12/dist-packages (from qiskit-finance) (0.3.4)
# Requirement already satisfied: setuptools>=40.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-finance) (75.2.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from qiskit-finance) (2.2.2)
# Requirement already satisfied: nasdaq-data-link in /usr/local/lib/python3.12/dist-packages (from qiskit-finance) (1.0.4)
# Requirement already satisfied: yfinance>=0.1.70 in /usr/local/lib/python3.12/dist-packages (from qiskit-finance) (0.2.66)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from qiskit-finance) (2026.2.25)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from qiskit-finance) (2.5.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.45->qiskit-finance) (0.17.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.45->qiskit-finance) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.45->qiskit-finance) (5.7.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.45->qiskit-finance) (4.15.0)
# Requirement already satisfied: docplex!=2.24.231,>=2.21.207 in /usr/local/lib/python3.12/dist-packages (from qiskit-optimization>=0.6.0->qiskit-finance) (2.32.259)
# Requirement already satisfied: networkx>=2.6.3 in /usr/local/lib/python3.12/dist-packages (from qiskit-optimization>=0.6.0->qiskit-finance) (3.6.1)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.1.70->qiskit-finance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.1.70->qiskit-finance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.1.70->qiskit-finance) (4.9.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.1.70->qiskit-finance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.1.70->qiskit-finance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.1.70->qiskit-finance) (4.0.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.1.70->qiskit-finance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.1.70->qiskit-finance) (0.14.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.1.70->qiskit-finance) (5.29.6)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance>=0.1.70->qiskit-finance) (15.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->qiskit-finance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->qiskit-finance) (2025.3)
# Requirement already satisfied: inflection>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from nasdaq-data-link->qiskit-finance) (0.5.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from nasdaq-data-link->qiskit-finance) (1.17.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from nasdaq-data-link->qiskit-finance) (10.8.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance>=0.1.70->qiskit-finance) (2.8.3)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance>=0.1.70->qiskit-finance) (2.0.0)
# Requirement already satisfied: hashable-list in /usr/local/lib/python3.12/dist-packages (from docplex!=2.24.231,>=2.21.207->qiskit-optimization>=0.6.0->qiskit-finance) (0.2.0)
# Requirement already satisfied: ordered-set in /usr/local/lib/python3.12/dist-packages (from docplex!=2.24.231,>=2.21.207->qiskit-optimization>=0.6.0->qiskit-finance) (4.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance>=0.1.70->qiskit-finance) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance>=0.1.70->qiskit-finance) (3.11)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance>=0.1.70->qiskit-finance) (3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit import transpile

qc = QuantumCircuit(1)
qc.h(0)
qc.measure_all()

sim = AerSimulator()

compiled = transpile(qc, sim)
result = sim.run(compiled).result()

print(result.get_counts())
# Out:
# {'1': 492, '0': 532}

# %%
import numpy as np

# Parameters
S0 = 100      # initial stock price
K = 110       # strike price
r = 0.05      # interest rate
sigma = 0.2   # volatility
T = 1         # time to maturity

simulations = 100000

# Generate random numbers
Z = np.random.standard_normal(simulations)

# Simulate stock price
ST = S0 * np.exp((r - 0.5 * sigma**2) * T + sigma * np.sqrt(T) * Z)

# Calculate payoff
payoff = np.maximum(ST - K, 0)

# Option price
option_price = np.exp(-r*T) * np.mean(payoff)

print("Estimated Option Price:", option_price)
# Out:
# Estimated Option Price: 6.016204388353679

# %%
# !pip install qiskit-aer
# Out:
# Collecting qiskit-aer
#   Downloading qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Requirement already satisfied: qiskit>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (2.3.1)
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (2.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (1.16.3)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer) (0.17.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer) (5.7.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer) (4.15.0)
# Downloading qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 96.0 MB/s eta 0:00:00
# Installing collected packages: qiskit-aer
# Successfully installed qiskit-aer-0.17.2

# %%
import matplotlib.pyplot as plt

plt.hist(ST, bins=50)
plt.title("Simulated Stock Price Distribution")
plt.xlabel("Stock Price")
plt.ylabel("Frequency")
plt.show()

# %%
print("Initial Stock Price:", S0)
print("Strike Price:", K)
print("Volatility:", sigma)
print("Option Price:", option_price)
# Out:
# Initial Stock Price: 100
# Strike Price: 110
# Volatility: 0.2
# Option Price: 6.016204388353679
